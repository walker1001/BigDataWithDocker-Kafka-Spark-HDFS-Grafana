# %%
from pyspark import SparkContext                                                                                        
from pyspark.sql import SparkSession                                                                                    
from pyspark.streaming import StreamingContext                                                                          
from pyspark.streaming.kafka import KafkaUtils    
import pandas as pd
import json

# %%
ss = SparkSession.Builder() \
     .appName("TEST") \
     .master("spark://spark-master:7077") \
     .config('spark.jars.packages', 'org.apache.spark:spark-streaming-kafka-0-8-assembly_2.11:2.4.1') \
     .config("spark.driver.allowMultipleContexts", "true") \
     .config("hive.metastore.uris", "thrift://hive-metastore:9083") \
     .config("spark.sql.warehouse.dir", "hdfs://namenode:9000/hive") \
     .enableHiveSupport() \
     .getOrCreate()

# ss = SparkSession.Builder() \
#      .appName("TEST") \
#      .master("spark://spark-master:7077") \
#      .enableHiveSupport() \
#      .getOrCreate()
# #
#org.apache.spark:spark-sql-kafka-0-10_2.11:2.4.1
#org.apache.spark:spark-streaming-kafka-0-8:2.4.1

# %%
# def handle_rdd(rdd):                                                                                                    
#     if not rdd.isEmpty():                                                                                               
#         global ss                                                                                                       
#         df = ss.createDataFrame(rdd, schema=[
#             "ArrivalTime",
#             "BusinessLeisure",
#             "CabinCategory",
#             "CreationDate",
#             "CurrencyCode",
#             "DepartureTime",
#             "Destination",
#             "OfficeIdCountry",
#             "Origin",
#             "TotalAmount",
#             "nPAX"])                                                
#         df.show()                                                                                                       
#         df.write.saveAsTable(name='default.tweets', format='hive', mode='append')        
def handle_rdd(rdd):
    if not rdd.isEmpty():
        global ss
        df = ss.createDataFrame(rdd, schema=['text', 'words', 'length'])
        df.show()
        df.write.saveAsTable(name='default.tweets', format='hive', mode='append')

# %%
sc = ss.sparkContext                                                                                    
ssc = StreamingContext(sc, 4)

# %%
ss.sparkContext.setLogLevel('WARN')                                                                                     
                                                                                                                        
ks = KafkaUtils.createDirectStream(ssc, ['tweets'], {'metadata.broker.list': 'kafka:9093'})                       
                                                                                                                        
lines = ks.map(lambda x: x[1])                                                                                          
                                                                                                                        
transform = lines.map(lambda tweet: (tweet, int(len(tweet.split())), int(len(tweet))))                                  
                                                                                                                        
transform.foreachRDD(handle_rdd)                                                                                        
                                                                                                                        
ssc.start()                                                                                                             
ssc.awaitTermination()
# Out:
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |Trump has launche...|   65|   368|
# +--------------------+-----+------+
#
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |At 6:31 a.m. loca...|  253|  1487|
# |The UK has ordere...|  141|   891|
# +--------------------+-----+------+
#
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |Former White Hous...|  145|   858|
# |What happens next...|   35|   225|
# +--------------------+-----+------+
#
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |"Covid-19 is a te...|  165|   936|
# |What happens next...|  108|   700|
# +--------------------+-----+------+
#
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |Nurse Joanna Sloa...|  241|  1369|
# |William Shakesper...|  139|   780|
# +--------------------+-----+------+
#
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |"It's the best ea...|  121|   678|
# |"And so my messag...|  257|  1507|
# +--------------------+-----+------+
#
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |The UK has ordere...|  193|  1183|
# |The 86-year-old, ...|  109|   571|
# +--------------------+-----+------+
#
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |Because the vacci...|  150|   833|
# |"And so my messag...|  231|  1279|
# +--------------------+-----+------+
#
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |Keenan, who turns...|   82|   483|
# |The UK has ordere...|  143|   855|
# +--------------------+-----+------+
#
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |The country has a...|  109|   577|
# |Biden won the pre...|  170|   957|
# +--------------------+-----+------+
#
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |The country has a...|  119|   716|
# |Former White Hous...|  157|   938|
# +--------------------+-----+------+
#
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |"It's the best ea...|   84|   429|
# |Cardiff, Wales (C...|  108|   593|
# +--------------------+-----+------+
#
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |The regulator, th...|  180|  1056|
# |What happens next...|   51|   314|
# +--------------------+-----+------+
#
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |The UK has ordere...|   84|   483|
# |A 90-year-old Bri...|  231|  1294|
# +--------------------+-----+------+
#
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |"Covid-19 is a te...|   84|   451|
# |"It's the best ea...|  113|   622|
# +--------------------+-----+------+
#
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |"It's the best ea...|  129|   664|
# |Former White Hous...|  257|  1615|
# +--------------------+-----+------+
#
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |"Covid-19 is a te...|  250|  1441|
# |Biden won the pre...|  168|  1020|
# +--------------------+-----+------+
#
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |"And so my messag...|  104|   578|
# |Nurse Joanna Sloa...|  165|   910|
# +--------------------+-----+------+
#
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |Because the vacci...|  123|   727|
# |The UK has ordere...|  130|   709|
# +--------------------+-----+------+
#
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |The country has a...|  227|  1341|
# |Keenan, who turns...|  267|  1543|
# +--------------------+-----+------+
#
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |Former White Hous...|  135|   799|
# |Nurse Joanna Sloa...|   55|   315|
# +--------------------+-----+------+
#
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |Biden won the pre...|  177|  1024|
# |"I would just say...|  255|  1373|
# +--------------------+-----+------+
#
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |The vaccine was f...|  115|   704|
# |"And so my messag...|  219|  1280|
# +--------------------+-----+------+
#
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |Former White Hous...|  160|   933|
# |The UK began its ...|  307|  1795|
# +--------------------+-----+------+
#
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |Gill Rogers, whos...|

# +--------------------+-----+------+
#
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |The 86-year-old, ...|   80|   475|
# |Gill Rogers, whos...|  151|   828|
# +--------------------+-----+------+
#
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |"The president wa...|  214|  1260|
# |"Covid-19 is a te...|  112|   572|
# +--------------------+-----+------+
#
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |Gill Rogers, whos...|  112|   647|
# |Asked whether he ...|   51|   306|
# +--------------------+-----+------+
#
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |The UK has ordere...|  203|  1105|
# |Trump has launche...|  195|  1113|
# +--------------------+-----+------+
#
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |Asked whether he ...|  205|  1160|
# |The vaccine was f...|  187|  1113|
# +--------------------+-----+------+
#
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |"I would just say...|  155|   872|
# |The first Briton ...|  224|  1242|
# +--------------------+-----+------+
#
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |Asked whether he ...|  112|   667|
# |The UK has ordere...|  224|  1351|
# +--------------------+-----+------+
#
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |The first Briton ...|  203|  1138|
# |Trump has launche...|   46|   253|
# +--------------------+-----+------+
#
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |The vaccine was f...|  255|  1550|
# |Biden won the pre...|   52|   360|
# +--------------------+-----+------+
#
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |The UK has ordere...|  179|  1017|
# |The country has a...|  220|  1266|
# +--------------------+-----+------+
#
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |Gill Rogers, whos...|   51|   292|
# |Cardiff, Wales (C...|  100|   607|
# +--------------------+-----+------+
#
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |The regulator, th...|  174|   996|
# |Asked whether he ...|   67|   408|
# +--------------------+-----+------+
#
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |A 90-year-old Bri...|   60|   330|
# |The UK has ordere...|  213|  1278|
# +--------------------+-----+------+
#
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |Nurse Joanna Sloa...|  159|   930|
# |A 90-year-old Bri...|  168|   983|
# +--------------------+-----+------+
#
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |Cardiff, Wales (C...|   98|   565|
# |Asked whether he ...|   60|   361|
# +--------------------+-----+------+
#
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |Keenan, who turns...|  108|   590|
# |The country has a...|   57|   308|
# +--------------------+-----+------+
#
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |"And so my messag...|   61|   319|
# |Nurse Joanna Sloa...|   83|   504|
# +--------------------+-----+------+
#
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |The country has a...|   30|   166|
# |The UK has ordere...|  134|   747|
# +--------------------+-----+------+
#
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |Former White Hous...|   76|   478|
# |The UK began its ...|  256|  1414|
# +--------------------+-----+------+
#
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |The regulator, th...|  138|   863|
# |"The president wa...|  194|  1052|
# +--------------------+-----+------+
#
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |The vaccine was f...|  145|   833|
# |Keenan, who turns...|  258|  1450|
# +--------------------+-----+------+
#
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |The vaccine was f...|  233|  1410|
# |The first Briton ...|  179|  1062|
# +--------------------+-----+------+
#
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |The regulator, th...|   71|   433|
# |Keenan, who turns...|  249|  1471|
# +--------------------+-----+------+
#
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |Gill Rogers, whos...|  208|  1215|
# |The vaccine was f...|  312|  1789|
# +--------------------+-----+------+
#
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |Gill Rogers, whos...|   61|   352|
# |The 86-year-old, ...|  160|   967|
# +--------------------+-----+------+
#
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |Keenan, who turns...|   74|   377|
# |Keenan, who turns...|  250|  1329|
# +--------------------+-----+------+
#
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |A 90-year-old Bri...|   60|   330|
# |At 6:31 a.m. loca...|  206|  1172|
# +--------------------+-----+------+
#
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |Because the vacci...|  192|  1154|
# |The 86-year-old, ...|  231|  1331|
# +--------------------+-----+------+
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |A 90-year-old Bri...|  160|   942|
# |Keenan, who turns...|  200|  1084|
# +--------------------+-----+------+
#
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |The regulator, th...|  124|   799|
# |"The president wa...|  176|  1024|
# +--------------------+-----+------+
#
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |The regulator, th...|  134|   768|
# |William Shakesper...|  253|  1470|
# +--------------------+-----+------+
#
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |"The president wa...|  274|  1573|
# |Gill Rogers, whos...|  283|  1740|
# +--------------------+-----+------+
#
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |The first Briton ...|   48|   277|
# |What happens next...|  144|   783|
# +--------------------+-----+------+
#
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |The first Briton ...|  130|   737|
# |The first Briton ...|  131|   776|
# +--------------------+-----+------+
#
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |"The president wa...|  132|   720|
# |The UK has ordere...|  207|  1184|
# +--------------------+-----+------+
#
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |The vaccine was f...|  247|  1435|
# |Asked whether he ...|  181|  1040|
# +--------------------+-----+------+
#
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |Cardiff, Wales (C...|   88|   552|
# |"Covid-19 is a te...|  184|  1066|
# +--------------------+-----+------+
#
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |Nurse Joanna Sloa...|   68|   395|
# |Trump has launche...|   35|   234|
# +--------------------+-----+------+
#
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |The 86-year-old, ...|  204|  1184|
# |William Shakesper...|  186|  1203|
# +--------------------+-----+------+
#
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |Keenan, who turns...|  253|  1449|
# |Because the vacci...|  169|  1027|
# +--------------------+-----+------+
#
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |Biden won the pre...|  142|   830|
# |Keenan, who turns...|   67|   368|
# +--------------------+-----+------+
#
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |The country has a...|  206|  1241|
# |"And so my messag...|  215|  1175|
# +--------------------+-----+------+
#
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |Trump has launche...|   86|   454|
# |At 6:31 a.m. loca...|   47|   315|
# +--------------------+-----+------+
#
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |The vaccine was f...|  172|   985|
# |A 90-year-old Bri...|  132|   723|
# +--------------------+-----+------+
#
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |Because the vacci...|  177|  1085|
# |Cardiff, Wales (C...|  159|   989|
# +--------------------+-----+------+
#
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |"Covid-19 is a te...|  276|  1575|
# |Gill Rogers, whos...|  110|   635|
# +--------------------+-----+------+
#
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |Gill Rogers, whos...|   75|   497|
# |The UK began its ...|  285|  1640|
# +--------------------+-----+------+
#
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |Gill Rogers, whos...|   56|   330|
# |Nurse Joanna Sloa...|  197|  1193|
# +--------------------+-----+------+
#
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |Gill Rogers, whos...|  188|  1091|
# |The UK has ordere...|   90|   567|
# +--------------------+-----+------+
#
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |"The president wa...|  193|  1036|
# |The UK has ordere...|  144|   832|
# +--------------------+-----+------+
#
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |Biden won the pre...|  120|   755|
# |A 90-year-old Bri...|   76|   422|
# +--------------------+-----+------+
#
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |The first Briton ...|  124|   775|
# |The UK has ordere...|  145|   813|
# +--------------------+-----+------+
#
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |Nurse Joanna Sloa...|  141|   887|
# |The vaccine was f...|  136|   857|
# +--------------------+-----+------+
#
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |The regulator, th...|  143|   856|
# |Cardiff, Wales (C...|  233|  1305|
# +--------------------+-----+------+
#
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |"Covid-19 is a te...|  116|   607|
# |Nurse Joanna Sloa...|  162|  1000|
# +--------------------+-----+------+
#
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |The country has a...|  185|  1057|
# |The 86-year-old, ...|  100|   521|
# +--------------------+-----+------+
#
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |William Shakesper...|  201|  1232|
# |Nurse Joanna Sloa...|   65|   394|
# +--------------------+-----+------+
#
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |"And so my messag...|  195|  1094|
# |Former White Hous...|  112|   637|
# +--------------------+-----+------+
#
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |The UK has ordere...|  174|  1041|
# |"And so my messag...|   53|   318|
# +--------------------+-----+------+
#
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |Asked whether he ...|   29|   162|
# |Keenan, who turns...|  163|   944|
# +--------------------+-----+------+
#
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |Keenan, who turns...|   66|   384|
# |The country has a...|  167|  1065|
# +--------------------+-----+------+
#
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |"I would just say...|  222|  1242|
# |The country has a...|  133|   759|
# +--------------------+-----+------+
#
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |What happens next...|   38|   252|
# |"And so my messag...|  157|   921|
# +--------------------+-----+------+
#
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |Cardiff, Wales (C...|  147|   802|
# |Former White Hous...|   92|   528|
# +--------------------+-----+------+
#
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |The first Briton ...|   82|   494|
# |Trump has launche...|   80|   430|
# +--------------------+-----+------+
#
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |Keenan, who turns...|   87|   527|
# |Gill Rogers, whos...|   92|   548|
# +--------------------+-----+------+
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |Asked whether he ...|  171|   988|
# |Keenan, who turns...|   97|   552|
# +--------------------+-----+------+
#
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |"It's the best ea...|  110|   594|
# |The country has a...|  170|  1000|
# +--------------------+-----+------+
#
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |What happens next...|  128|   677|
# |The UK has ordere...|   95|   529|
# +--------------------+-----+------+
#
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |The UK has ordere...|   49|   279|
# |Keenan, who turns...|   38|   201|
# +--------------------+-----+------+
#
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |The UK has ordere...|  148|   830|
# |At 6:31 a.m. loca...|  111|   631|
# +--------------------+-----+------+
#
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |The first Briton ...|  171|   924|
# |The UK began its ...|  114|   707|
# +--------------------+-----+------+
#
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |Nurse Joanna Sloa...|  124|   682|
# |Trump has launche...|   52|   316|
# +--------------------+-----+------+
#
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |At 6:31 a.m. loca...|  207|  1106|
# |Asked whether he ...|  178|  1071|
# +--------------------+-----+------+
#
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |Nurse Joanna Sloa...|   99|   546|
# |What happens next...|  102|   563|
# +--------------------+-----+------+
#
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |"The president wa...|  162|   933|
# |A 90-year-old Bri...|  235|  1246|
# +--------------------+-----+------+
#
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |Nurse Joanna Sloa...|  155|   915|
# |"I would just say...|  110|   623|
# +--------------------+-----+------+
#
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |"I would just say...|  195|  1131|
# |Keenan, who turns...|   46|   272|
# +--------------------+-----+------+
#
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |What happens next...|  161|   923|
# |The country has a...|  131|   730|
# +--------------------+-----+------+
#
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |Gill Rogers, whos...|   50|   302|
# |Gill Rogers, whos...|  159|   931|
# +--------------------+-----+------+
#
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |A 90-year-old Bri...|  186|  1067|
# |What happens next...|   95|   486|
# +--------------------+-----+------+
#
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |A 90-year-old Bri...|  180|  1074|
# |Gill Rogers, whos...|  118|   679|
# +--------------------+-----+------+
#
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |Asked whether he ...|   74|   450|
# |Nurse Joanna Sloa...|  223|  1331|
# +--------------------+-----+------+
#
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |Cardiff, Wales (C...|  260|  1536|
# |Former White Hous...|  132|   746|
# +--------------------+-----+------+
#
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |Former White Hous...|  172|  1065|
# |Trump has launche...|   42|   237|
# +--------------------+-----+------+
#
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |Nurse Joanna Sloa...|  251|  1345|
# |Keenan, who turns...|  182|  1018|
# +--------------------+-----+------+
#
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |Because the vacci...|  181|   994|
# |Gill Rogers, whos...|  116|   660|
# +--------------------+-----+------+
#
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |Biden won the pre...|  203|  1230|
# |Asked whether he ...|  151|   939|
# +--------------------+-----+------+
#
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |Gill Rogers, whos...|  131|   781|
# |Gill Rogers, whos...|   83|   499|
# +--------------------+-----+------+
#
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |A 90-year-old Bri...|   45|   263|
# |The UK has ordere...|  145|   838|
# +--------------------+-----+------+
#
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |The vaccine was f...|  196|  1198|
# |Cardiff, Wales (C...|  206|  1276|
# +--------------------+-----+------+
#
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |The UK has ordere...|  230|  1366|
# |Former White Hous...|  303|  1720|
# +--------------------+-----+------+
#
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |What happens next...|  132|   800|
# |The country has a...|   81|   516|
# +--------------------+-----+------+
#
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |What happens next...|   68|   359|
# |Because the vacci...|  192|  1184|
# +--------------------+-----+------+
#
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |Gill Rogers, whos...|  259|  1462|
# |"And so my messag...|  332|  1811|
# +--------------------+-----+------+
#
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |Gill Rogers, whos...|   79|   489|
# |The vaccine was f...|  230|  1314|
# +--------------------+-----+------+
#
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |Gill Rogers, whos...|  260|  1454|
# |The vaccine was f...|  199|  1223|
# +--------------------+-----+------+
#
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |William Shakesper...|  224|  1291|
# |Keenan, who turns...|  133|   734|
# +--------------------+-----+------+
#
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |Nurse Joanna Sloa...|  167|   939|
# |William Shakesper...|  161|  1017|
# +--------------------+-----+------+
#
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |"It's the best ea...|  167|   973|
# |"And so my messag...|  159|   857|
# +--------------------+-----+------+
#
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |At 6:31 a.m. loca...|  150|   924|
# |"I would just say...|  206|  1163|
# +--------------------+-----+------+
#
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |The 86-year-old, ...|  113|   649|
# |The regulator, th...|  256|  1525|
# +--------------------+-----+------+
#
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |What happens next...|  152|   884|
# |Former White Hous...|  125|   715|
# +--------------------+-----+------+
#
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |The UK began its ...|  265|  1704|
# |Former White Hous...|  197|  1183|
# +--------------------+-----+------+
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |The first Briton ...|  246|  1358|
# |William Shakesper...|   65|   418|
# +--------------------+-----+------+
#
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |"Covid-19 is a te...|  234|  1278|
# |Trump has launche...|  187|  1125|
# +--------------------+-----+------+
#
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |"Covid-19 is a te...|   88|   476|
# |The vaccine was f...|  123|   783|
# +--------------------+-----+------+
#
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |Gill Rogers, whos...|  231|  1377|
# |The country has a...|   78|   472|
# +--------------------+-----+------+
#
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |The UK has ordere...|  153|   936|
# |Cardiff, Wales (C...|  234|  1321|
# +--------------------+-----+------+
#
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |The regulator, th...|  186|  1075|
# |William Shakesper...|  214|  1242|
# +--------------------+-----+------+
#
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |"It's the best ea...|   97|   527|
# |Former White Hous...|  125|   773|
# +--------------------+-----+------+
#
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |"The president wa...|  204|  1130|
# |The UK has ordere...|   76|   392|
# +--------------------+-----+------+
#
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |The country has a...|   99|   549|
# |Cardiff, Wales (C...|   61|   400|
# +--------------------+-----+------+
#
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |"I would just say...|   68|   360|
# |A 90-year-old Bri...|  162|   986|
# +--------------------+-----+------+
#
# +--------------------+-----+------+
# |                text|words|length|
# +--------------------+-----+------+
# |Gill Rogers, whos...|   55|   307|
# +--------------------+-----+------+
